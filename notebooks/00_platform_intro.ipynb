# %% [markdown]
# # Graph Algorithms Platform Intro
#
# This notebook shows the four core platform layers added around the SCC implementations:
#
# - algorithm registry
# - reusable graph loaders
# - benchmark export
# - teaching notebooks

# %%
from algorithms.registry import list_algorithms, run_algorithm
from graph_io.examples import list_examples, load_example_graph

print(list_examples())
print([algorithm.key for algorithm in list_algorithms(category="scc")])

# %%
graph = load_example_graph("two_sccs")
result = run_algorithm("tarjan", graph)

print(result.algorithm_name)
print(result.component_count)
print(result.component_map)
